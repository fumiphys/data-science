# %% [markdown]
# # VGG16
# reference: http://aidiary.hatenablog.com/entry/20170104/1483535144

# %%
import numpy as np
from keras.applications.vgg16 import VGG16, decode_predictions, preprocess_input
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.
# /Users/fkiyozawa/.pyenv/versions/3.6.0/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/fkiyozawa/.pyenv/versions/3.6.0/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# data
imagef = "./cat.jpg"

# %%
# define model
model = VGG16(weights='imagenet')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
img = image.load_img(imagef, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

# %%
print(x.shape)
img
# Out:
# (1, 224, 224, 3)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x112567160>

# %%
# predict
prediction = model.predict(preprocess_input(x))
result = decode_predictions(prediction, top=5)[0]

# %%
print(result)
# Out:
# [('n02123045', 'tabby', 0.17389277), ('n02124075', 'Egyptian_cat', 0.13426657), ('n02123159', 'tiger_cat', 0.12374266), ('n02971356', 'carton', 0.09463768), ('n04493381', 'tub', 0.029769538)]

# %%
imgx = image.load_img("/Users/fkiyozawa/Downloads/other/vK2EdBy__400x400.jpg", target_size=(224, 224))

# %%
xx = image.img_to_array(imgx)
xx = np.expand_dims(xx, axis=0)

# %%
predictionx = model.predict(preprocess_input(xx))
result = decode_predictions(predictionx, top=5)[0]

# %%
print(result)
# Out:
# [('n04399382', 'teddy', 0.69066745), ('n13044778', 'earthstar', 0.1454353), ('n13052670', 'hen-of-the-woods', 0.020485874), ('n04462240', 'toyshop', 0.01872521), ('n04599235', 'wool', 0.018382823)]

# %%
imgx
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x126614FD0>
